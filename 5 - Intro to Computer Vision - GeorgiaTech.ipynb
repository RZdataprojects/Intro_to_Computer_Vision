# %% [markdown]
# # Correlation, Template Matching
#
# Template matching is the process of locating a template or a pattern in an image using cross correlation.

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
# %matplotlib inline

img = cv2.imread('/content/drive/MyDrive/media/pexels-jack-hawley-57905.jpg')
template = img[110:213, 120:234]
cv2_imshow(template)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=114x103 at 0x7FB58875D1C0>
# <PIL.Image.Image image mode=RGB size=640x427 at 0x7FB58875D6D0>

# %%
result = cv2.matchTemplate(img, section, cv.TM_CCOEFF_NORMED)
threshold = 0.95
location = np.where(result >= threshold)

#draw a rectengle around the probable location

# Store width and height of template in w and h
w, h = template.shape[0:2]
 
for pt in zip(*location[::-1]):
   cv2.rectangle(img, pt, (pt[0] + w, pt[1] + h), (0, 255, 255), 2)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x427 at 0x7FB588BD1850>

# %% [markdown]
# Template matching is a powerful tool, but image rotation and sizing can impare the accuracy greatly.
